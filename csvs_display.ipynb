# %%
import pandas as pd

# %%
pd.read_csv('results/csvs/increase_freq_PIRATE').tail()
# Out:
#          Unnamed: 0     BS  EPOCHS  FREQ              learnable_func  \
# 5   increase_freq_6  16384    2500     6  circular_wave_interference
# 6   increase_freq_7  16384    2500     7  circular_wave_interference
# 7   increase_freq_8  16384    2500     8  circular_wave_interference
# 8   increase_freq_9  16384    2500     9  circular_wave_interference
# 9  increase_freq_10  16384    2500    10  circular_wave_interference
#
#    FourierFeatures   MODEL            layers  N_INPUT  X_MIN  X_MAX  Y_MIN  \
# 5             True  PIRATE  [32, 32, 32, 32]        2     -1      1     -1
# 6             True  PIRATE  [32, 32, 32, 32]        2     -1      1     -1
# 7             True  PIRATE  [32, 32, 32, 32]        2     -1      1     -1
# 8             True  PIRATE  [32, 32, 32, 32]        2     -1      1     -1
# 9             True  PIRATE  [32, 32, 32, 32]        2     -1      1     -1
#
#    Y_MAX  params       L2%   seconds
# 5      1   11700  0.418322  5.594751
# ...

# %%
pd.read_csv('results/csvs/increase_freq_fourier').tail()
# Out:
#          Unnamed: 0     BS  EPOCHS  FREQ              learnable_func  \
# 5   increase_freq_6  16384    2500     6  circular_wave_interference
# 6   increase_freq_7  16384    2500     7  circular_wave_interference
# 7   increase_freq_8  16384    2500     8  circular_wave_interference
# 8   increase_freq_9  16384    2500     9  circular_wave_interference
# 9  increase_freq_10  16384    2500    10  circular_wave_interference
#
#    FourierFeatures MODEL            layers  N_INPUT  X_MIN  X_MAX  Y_MIN  \
# 5             True   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 6             True   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 7             True   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 8             True   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 9             True   MLP  [64, 64, 64, 64]        2     -1      1     -1
#
#    Y_MAX  params       L2%   seconds
# 5      1   12641  0.570408  1.717848
# ...

# %%
pd.read_csv('results/csvs/increase_freq_KAN_Fourier').tail()
# Out:
#          Unnamed: 0     BS  EPOCHS  FREQ              learnable_func  \
# 5   increase_freq_6  16384    2500     6  circular_wave_interference
# 6   increase_freq_7  16384    2500     7  circular_wave_interference
# 7   increase_freq_8  16384    2500     8  circular_wave_interference
# 8   increase_freq_9  16384    2500     9  circular_wave_interference
# 9  increase_freq_10  16384    2500    10  circular_wave_interference
#
#    FourierFeatures MODEL        layers  N_INPUT  X_MIN  X_MAX  Y_MIN  Y_MAX  \
# 5             True   KAN  [32, 32, 16]        2     -1      1     -1      1
# 6             True   KAN  [32, 32, 16]        2     -1      1     -1      1
# 7             True   KAN  [32, 32, 16]        2     -1      1     -1      1
# 8             True   KAN  [32, 32, 16]        2     -1      1     -1      1
# 9             True   KAN  [32, 32, 16]        2     -1      1     -1      1
#
#    params       L2%    seconds
# 5   12513  2.357409  47.633120
# ...

# %%
pd.read_csv('results/csvs/increase_freq_KAN').tail()
# Out:
#          Unnamed: 0     BS  EPOCHS  FREQ              learnable_func  \
# 5   increase_freq_6  16384    2500     6  circular_wave_interference
# 6   increase_freq_7  16384    2500     7  circular_wave_interference
# 7   increase_freq_8  16384    2500     8  circular_wave_interference
# 8   increase_freq_9  16384    2500     9  circular_wave_interference
# 9  increase_freq_10  16384    2500    10  circular_wave_interference
#
#    FourierFeatures MODEL        layers  N_INPUT  X_MIN  X_MAX  Y_MIN  Y_MAX  \
# 5            False   KAN  [32, 32, 14]        2     -1      1     -1      1
# 6            False   KAN  [32, 32, 14]        2     -1      1     -1      1
# 7            False   KAN  [32, 32, 14]        2     -1      1     -1      1
# 8            False   KAN  [32, 32, 14]        2     -1      1     -1      1
# 9            False   KAN  [32, 32, 14]        2     -1      1     -1      1
#
#    params        L2%    seconds
# 5   12479   5.044598  44.503668
# ...

# %%
pd.read_csv('results/csvs/increase_freq_nofourier').tail()
# Out:
#          Unnamed: 0     BS  EPOCHS  FREQ              learnable_func  \
# 5   increase_freq_6  16384    2500     6  circular_wave_interference
# 6   increase_freq_7  16384    2500     7  circular_wave_interference
# 7   increase_freq_8  16384    2500     8  circular_wave_interference
# 8   increase_freq_9  16384    2500     9  circular_wave_interference
# 9  increase_freq_10  16384    2500    10  circular_wave_interference
#
#    FourierFeatures MODEL            layers  N_INPUT  X_MIN  X_MAX  Y_MIN  \
# 5            False   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 6            False   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 7            False   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 8            False   MLP  [64, 64, 64, 64]        2     -1      1     -1
# 9            False   MLP  [64, 64, 64, 64]        2     -1      1     -1
#
#    Y_MAX  params        L2%   seconds
# 5      1   12737   4.428979  1.633353
# ...

# %% [markdown]
# # Performance high freq
# 1. PIRATE
# 2. MLP + FourierFeatures
# 3. KAN + FourierFeatures
# 4. KAN
# 5. MLP

# %% [markdown]
# # PDEs implementadas
# - HelmHoltz 1% L2
# - Heat 1% L2
# - Burgers 5% L2 (mejorar con tiempo)

# %%
# !pip freeze > requirements.txt
